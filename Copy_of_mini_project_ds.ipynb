# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh-mano-4/Instagram-clone/blob/main/Copy_of_mini_project_ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
import pandas as pd
cities = pd.read_csv("california_cities.csv")
print(cities.head())
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
a=cities['population_total'].mean()
print(a)
# Out:
# 64894.933609958505

# %%
a=cities['population_total'].median()
print(a)
# Out:
# 29057.5

# %%
a=cities['population_total'].mode()
print(a)
# Out:
# 0    11926
# dtype: int64

# %%
a=cities['population_total'].var()
print(a)
# Out:
# 41291904905.85005

# %%
a=cities['population_total'].std()
print(a)
# Out:
# 203204.09667585458

# %%
a=cities['population_total'].max()
print(a)
# Out:
# 3884307

# %%
a=cities['population_total'].min()
print(a)
# Out:
# 1

# %%
a=cities['population_total'].var()
print(a)
# Out:
# 41291904905.85005

# %%
max=cities['population_total'].max()
min=cities['population_total'].min()
range=max-min
print(range)
# Out:
# 3884306

# %%
f=cities.var()
print(f)
# Out:
# Unnamed: 0            1.940050e+04
# latd                  5.280831e+00
# longd                 4.612514e+00
# elevation_m           9.580995e+04
# elevation_ft          1.002533e+06
# population_total      4.129190e+10
# area_total_sq_mi      1.322285e+03
# area_land_sq_mi       1.068940e+03
# area_water_sq_mi      9.006743e+01
# area_total_km2        8.275954e+03
# area_land_km2         7.213618e+03
# area_water_km2        1.336861e+02
# area_water_percent    2.148109e+02
# dtype: float64
# <ipython-input-36-e5f8b14cf6e8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   f=cities.var()

# %%
cities.skew()
# Out:
# <ipython-input-37-f14d367142cd>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cities.skew()
# Unnamed: 0             0.000000
# latd                   0.399179
# longd                  0.025650
# elevation_m            3.461215
# elevation_ft           3.501817
# population_total      14.792513
# area_total_sq_mi       8.071141
# area_land_sq_mi        8.305793
# area_water_sq_mi      15.671221
# area_total_km2         8.562238
# area_land_km2          8.291815
# area_water_km2         5.729240
# area_water_percent     3.708323
# dtype: float64

# %%
latitude, longitude = cities["latd"], cities["longd"]
population, area = cities["population_total"], cities["area_total_km2"]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
plt.scatter(longitude, latitude, label=None, c=np.log10(population),
            cmap='viridis', s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('Longitude')
plt.ylabel('Longitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area, label=str(area) + 'km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Areas')
plt.title("Area and Population of California Cities")
plt.show()
# Out:
# <ipython-input-8-724370c02751>:7: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   plt.axis(aspect='equal')

# %%
import matplotlib.pyplot as plt
x=cities['population_total']
y=cities['area_total_km2']
plt.title("Area and Population of California Cities")
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
c=cities['elevation_m']
plt.hist(c,edgecolor="black")
# Out:
# (array([336.,  57.,   8.,  18.,   4.,   5.,   2.,   2.,   1.,   1.]),
#  array([ -34. ,  209.6,  453.2,  696.8,  940.4, 1184. , 1427.6, 1671.2,
#         1914.8, 2158.4, 2402. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
cities=pd.read_csv('california_cities.csv')
cities.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
print(cities.describe())
# Out:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  482.000000  482.000000  482.000000   434.000000    470.000000
# mean   240.500000   36.095088 -119.837714   180.416705    567.168723
# std    139.285678    2.298006    2.147676   309.531825   1001.265722
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    120.250000   33.977292 -121.954931    22.000000     69.000000
# 50%    240.500000   36.204722 -119.708611    67.000000    200.000000
# 75%    360.750000   37.886667 -117.977292   173.500000    515.000000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.820000e+02        480.000000       482.000000        481.000000
# mean       6.489493e+04         18.442183        16.840981          1.589630
# std        2.032041e+05         36.363230        32.694647          9.490386
# ...

# %%
print(cities.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB
# None

# %%
x=cities['population_total']
y=cities['area_total_km2']
x.head()
y.head()
# Out:
# 0    145.107
# 1     20.260
# 2     59.465
# 3     14.155
# 4     19.766
# Name: area_total_km2, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (482,)
# (482,)

# %%
x=x.values.reshape(-1,1)
x.shape
# Out:
# (482, 1)

# %% [markdown]
# USING 3D

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x=cities['population_total']
y=cities['area_total_km2']
z=c=cities['elevation_m']
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(x, y, z, 'grey')
plt.show()

# %%
cities.plot("population_total",legend=True)

# %%
cities.plot("area_total_km2",legend=True)
